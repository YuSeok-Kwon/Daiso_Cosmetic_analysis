# %% [markdown]
# # CSV 파일 매칭 검증
# 같은 카테고리의 product CSV와 review CSV를 비교하여 불일치 확인

# %%
import pandas as pd
import glob
import os
import re

data_dir = '/Users/yu_seok/Documents/workspace/nbCamp/Project/Why-pi/data/csv'
product_files = glob.glob(os.path.join(data_dir, 'product_*.csv'))
review_files = glob.glob(os.path.join(data_dir, 'reviews_*.csv'))

print(f"product CSV: {len(product_files)}개")
print(f"reviews CSV: {len(review_files)}개\n")

def extract_category(filename):
    """product_메이크업_all_20260204.csv -> 메이크업_all_20260204"""
    basename = os.path.basename(filename)
    if basename.startswith('product_'):
        return basename.replace('product_', '').replace('.csv', '')
    elif basename.startswith('reviews_'):
        return basename.replace('reviews_', '').replace('.csv', '')
    return None

# 파일 매칭
product_dict = {extract_category(f): f for f in product_files}
review_dict = {extract_category(f): f for f in review_files}

print("="*80)
print("파일 매칭")
print("="*80)

all_categories = set(product_dict.keys()) | set(review_dict.keys())

for category in sorted(all_categories):
    has_product = category in product_dict
    has_review = category in review_dict
    
    status = "[OK]" if (has_product and has_review) else "[WARNING]"
    
    print(f"{status} {category}")
    if has_product:
        print(f"   product: {os.path.basename(product_dict[category])}")
    else:
        print(f"   product: 없음")
    
    if has_review:
        print(f"   reviews: {os.path.basename(review_dict[category])}")
    else:
        print(f"   reviews: 없음")
    print()
# Out:
# product CSV: 4개
# reviews CSV: 4개
#
# ================================================================================
# 파일 매칭
# ================================================================================
# [OK] 메이크업_베이스:립메이크업_20260204
#    product: product_메이크업_베이스:립메이크업_20260204.csv
#    reviews: reviews_메이크업_베이스:립메이크업_20260204.csv
#
# [OK] 맨케어_all_20260204
#    product: product_맨케어_all_20260204.csv
#    reviews: reviews_맨케어_all_20260204.csv
#
# [OK] 메이크업_아이메이크업_20260204
#    product: product_메이크업_아이메이크업_20260204.csv
#    reviews: reviews_메이크업_아이메이크업_20260204.csv
#
# [OK] 메이크업_치크_하이라이터_20260204
#    product: product_메이크업_치크_하이라이터_20260204.csv
#    reviews: reviews_메이크업_치크_하이라이터_20260204.csv

# %%
matched_categories = set(product_dict.keys()) & set(review_dict.keys())

print("="*80)
print("카테고리별 product_code 매칭 검증")
print("="*80)
print()

total_only_product = 0
total_only_review = 0
total_matched = 0

for category in sorted(matched_categories):
    product_file = product_dict[category]
    review_file = review_dict[category]
    
    # CSV 읽기
    product_df = pd.read_csv(product_file)
    review_df = pd.read_csv(review_file)
    
    # product_code 추출
    product_codes = set(product_df['product_code'].dropna().astype(int))
    review_codes = set(review_df['product_code'].dropna().astype(int))
    
    # 매칭 확인
    both = product_codes & review_codes
    only_product = product_codes - review_codes
    only_review = review_codes - product_codes
    
    total_matched += len(both)
    total_only_product += len(only_product)
    total_only_review += len(only_review)
    
    print(f"{'='*80}")
    print(f"[{category}]")
    print(f"{'='*80}")
    print(f"  product CSV: {len(product_codes)}개")
    print(f"  reviews CSV: {len(review_codes)}개")
    print()
    print(f"  [OK] 매칭됨 (product & review 모두): {len(both)}개")
    
    if len(only_product) > 0:
        print(f"  [WARNING] product만 있음 (리뷰 없음): {len(only_product)}개")
        if len(only_product) <= 10:
            print(f"     코드: {sorted(only_product)}")
        else:
            print(f"     처음 10개: {sorted(only_product)[:10]}")
    
    if len(only_review) > 0:
        print(f"  [ERROR] review만 있음 (제품 정보 없음): {len(only_review)}개")
        if len(only_review) <= 10:
            print(f"     코드: {sorted(only_review)}")
        else:
            print(f"     처음 10개: {sorted(only_review)[:10]}")
    
    print()
# Out:
# ================================================================================
# 카테고리별 product_code 매칭 검증
# ================================================================================
#
# ================================================================================
# [메이크업_베이스:립메이크업_20260204]
# ================================================================================
#   product CSV: 237개
#   reviews CSV: 237개
#
#   [OK] 매칭됨 (product & review 모두): 237개
#
# ================================================================================
# [맨케어_all_20260204]
# ================================================================================
#   product CSV: 73개
#   reviews CSV: 72개
#
#   [OK] 매칭됨 (product & review 모두): 72개
#   [WARNING] product만 있음 (리뷰 없음): 1개
#      코드: [1059931]
#
# ================================================================================
# [메이크업_아이메이크업_20260204]
# ================================================================================
#   product CSV: 128개
#   reviews CSV: 124개
#
#   [OK] 매칭됨 (product & review 모두): 124개
#   [WARNING] product만 있음 (리뷰 없음): 4개
#      코드: [1069087, 1069088, 1069089, 1069090]
#
# ================================================================================
# [메이크업_치크_하이라이터_20260204]
# ================================================================================
#   product CSV: 81개
#   reviews CSV: 81개
#
#   [OK] 매칭됨 (product & review 모두): 81개

# %%
# 전체 요약
print(f"\n{'='*80}")
print("전체 요약")
print(f"{'='*80}")
print(f"  검증한 카테고리: {len(matched_categories)}개")
print(f"  [OK] 매칭됨: {total_matched}개")
print(f"  [WARNING] product만 있음: {total_only_product}개")
print(f"  [ERROR] review만 있음: {total_only_review}개")
print()

if total_only_product == 0 and total_only_review == 0:
    print("  [OK] 모든 파일이 완벽하게 매칭됩니다!")
elif total_only_review > 0:
    print(f"  [ERROR] {total_only_review}개 제품의 리뷰만 있고 제품 정보가 없습니다!")
elif total_only_product > 0:
    print(f"  [INFO] {total_only_product}개 제품은 리뷰가 없습니다 (정상)")
# Out:
# ================================================================================
# 전체 요약
# ================================================================================
#   검증한 카테고리: 4개
#   [OK] 매칭됨: 514개
#   [WARNING] product만 있음: 5개
#   [ERROR] review만 있음: 0개
#
#   [INFO] 5개 제품은 리뷰가 없습니다 (정상)

# %%
all_products = []

for product_file in product_files:
    df = pd.read_csv(product_file)
    if 'brand' in df.columns and 'name' in df.columns:
        all_products.append(df[['brand', 'name', 'product_code']])

# 전체 데이터 병합
if all_products:
    combined_df = pd.concat(all_products, ignore_index=True)
    
    print("="*80)
    print("전체 통계")
    print("="*80)
    print(f"총 제품 수: {len(combined_df)}개")
    print(f"고유 브랜드 수: {combined_df['brand'].nunique()}개")
    print()
    
    # 브랜드별 제품 수
    brand_counts = combined_df['brand'].value_counts()
    
    print("="*80)
    print("브랜드별 제품 수")
    print("="*80)
    for brand, count in brand_counts.items():
        if pd.notna(brand) and brand != '':
            print(f"{brand}: {count}개")
        else:
            print(f"[브랜드 없음]: {count}개")
    
    print()
    print("="*80)
    print("브랜드별 상품 목록")
    print("="*80)
    
    # 브랜드별로 그룹핑하여 상품명 출력
    for brand in sorted(combined_df['brand'].unique()):
        if pd.isna(brand) or brand == '':
            brand_name = "[브랜드 없음]"
        else:
            brand_name = brand
        
        products = combined_df[combined_df['brand'] == brand]
        
        print(f"\n[{brand_name}] ({len(products)}개)")
        print("-"*80)
        
        for idx, row in products.iterrows():
            print(f"  - {row['name']}")
else:
    print("제품 데이터가 없습니다.")
# Out:
# ================================================================================
# 전체 통계
# ================================================================================
# 총 제품 수: 519개
# 고유 브랜드 수: 71개
#
# ================================================================================
# 브랜드별 제품 수
# ================================================================================
# 태그: 42개
# 머지: 36개
# 투에딧: 32개
# 프릴루드 딘토: 31개
# 입큰: 30개
# 본셉 메이크업: 29개
# 트윙클팝: 27개
# 손앤박: 26개
# 플레이101 by 에뛰드: 25개
# 밀크터치 디어씽: 21개
# 드롭비 컬러즈: 19개
# 줌 바이 정샘물: 11개
# 코시에로: 10개
# 코코가가: 10개
# 클라뷰: 9개
# 스타일리쉬: 8개
# 더봄: 7개
# 베리썸: 7개
# 쉬크: 7개
# [01: 7개
# [02: 7개
# 싸이닉: 6개
# 프렙 바이 비레디: 6개
# 더랩 바이 블랑두: 6개
# 데일리콤마: 6개
# 어퓨_더퓨어: 5개
# 도루코: 5개
# 보닌: 4개
# KAI: 4개
# NEW: 4개
# 파넬: 4개
# 애교살: 3개
# 윙크걸: 3개
# 러블리: 3개
# 코드글로컬러: 3개
# [03: 3개
# 오릭스: 3개
# 하드: 2개
# 맨넨: 2개
# 닥터지오: 2개
# [04: 2개
# 도루코윈3: 2개
# 도루코윈4: 2개
# 6중날: 2개
# 도루코윈: 2개
# 멘넨: 2개
# 제이엠솔루션: 2개
# 미팩토리: 2개
# 클리덤: 2개
# 식물원: 2개
# 플랫형: 2개
# 펜슬: 2개
# 펠트: 2개
# 스니키: 1개
# 눈썹: 1개
# 3중: 1개
# 둥근형: 1개
# 도루코TG2플러스5P: 1개
# 3중날: 1개
# 2중날: 1개
# 펜슬＆브러쉬: 1개
# 방수: 1개
# 남성용다리털정리기: 1개
# 그로우어스: 1개
# 전동: 1개
# 심플: 1개
# 비알티씨: 1개
# 캐릭터: 1개
# 수채화: 1개
# 잇츠스킨: 1개
# 카이지루시: 1개
#
# ================================================================================
# 브랜드별 상품 목록
# ================================================================================
#
# [2중날] (1개)
# --------------------------------------------------------------------------------
#   - 2중날 휴대용 면도기 10개입
#
# [3중] (1개)
# --------------------------------------------------------------------------------
#   - 3중 날 시스템 면도기 리필 4개입
#
# [3중날] (1개)
# --------------------------------------------------------------------------------
#   - 3중날 시스템 면도기 면도날 세트
#
# [6중날] (2개)
# --------------------------------------------------------------------------------
#   - 6중날 시스템 면도기 리필 세트
#   - 6중날 오픈 카트리지 면도기 1P
#
# [KAI] (4개)
# --------------------------------------------------------------------------------
#   - KAI 2중날 면도기 10개입
#   - KAI 2중날 면도기 20개입
#   - KAI 베스티 EX 면도기 4개입
#   - KAI 2중날 고정식 면도기 5개입
#
# [NEW] (4개)
# --------------------------------------------------------------------------------
#   - NEW 스타일리쉬 오토 아이라이너 펜슬 브라운
#   - NEW 스타일리쉬 오토 아이라이너 펜슬 블랙
#   - NEW 스타일리쉬 오토 립 라이너 펜슬 베리쉬폰
#   - NEW 스타일리쉬 오토 립 라이너 펜슬 크림핑크
#
# [[01] (7개)
# --------------------------------------------------------------------------------
#   - [01 클리어] 파넬 피치마누 글로우밤 하이라이터
#   - [01 플러피 핑크] 코드글로컬러 소프트 블러 리퀴드 블러셔
#   - [01 딥브라운] 더봄 스키니브로우 펜슬
#   - [01 클리어] 파넬 피치마누 브로우 래쉬세럼 쉐이퍼
#   - [01 퓨어] 코드글로컬러 컨실레놀 10 g
#   - [01 퓨어피치] 파넬 피치마누 글로우 립세럼
#   - [01 크랜베리 에이드] 코드글로컬러 프루티 볼륨 립글로스
#
# [[02] (7개)
# --------------------------------------------------------------------------------
#   - [02 핑크] 파넬 피치마누 글로우밤 하이라이터
#   - [02 로즈 블러쉬] 코드글로컬러 소프트 블러 리퀴드 블러셔
#   - [02 내추럴브라운] 더봄 스키니브로우 펜슬
#   - [02 애쉬브라운] 파넬 피치마누 브로우 래쉬세럼 쉐이퍼
#   - [02 피치] 코드글로컬러 컨실레놀 10 g
#   - [02 코랄] 파넬 피치마누 글로우 립세럼
#   - [02 애플팝] 코드글로컬러 프루티 볼륨 립글로스
#
# [[03] (3개)
# --------------------------------------------------------------------------------
#   - [03 피치부케] 코드글로컬러 소프트 블러 리퀴드 블러셔
#   - [03 소프트그레이] 더봄 스키니브로우 펜슬
#   - [03 펀치 오렌지] 코드글로컬러 프루티 볼륨 립글로스
#
# [[04] (2개)
# --------------------------------------------------------------------------------
#   - [04 토프베이지] 더봄 스키니브로우 펜슬
#   - [04 베어 핑크] 코드글로컬러 프루티 볼륨 립글로스
#
# [그로우어스] (1개)
# --------------------------------------------------------------------------------
#   - 그로우어스 롱래스팅 클리어 앤 틴팅 2IN1 래쉬세럼
#
# [남성용다리털정리기] (1개)
# --------------------------------------------------------------------------------
#   - 남성용다리털정리기
#
# [눈썹] (1개)
# --------------------------------------------------------------------------------
#   - 눈썹 그리기도구 4개입
#
# [닥터지오] (2개)
# --------------------------------------------------------------------------------
#   - 닥터지오 모이스처 올인원 젤로션 150ml
#   - 닥터지오 시카진정 올인원 밀크플루이드 150 ml
#
# [더랩 바이 블랑두] (6개)
# --------------------------------------------------------------------------------
#   - 더랩 바이 블랑두 클리어 히알 물광 틴티드 커버 크림 40 ml
#   - 더랩바이블랑두 클리어히알옴므 톤 커버크림 30 ml
#   - 더랩바이블랑두 클리어히알옴므 클렌징폼 120 ml
#   - 더랩바이블랑두 클리어히알옴므 올인원에멀전 120 ml
#   - 더랩바이블랑두 클리어히알옴므 토너 200 ml
#   - 더랩바이블랑두 클리어히알옴므 선크림 35 ml
#
# [더봄] (7개)
# --------------------------------------------------------------------------------
#   - 더봄 애교살＆트임 펜슬 (음영 브라운)
#   - 더봄 애교살＆트임 펜슬 (핑크 로지)
#   - 더봄 애교살＆트임 펜슬(볼륨베이지)
#   - 더봄 애교살＆트임 펜슬 (살몬 핑크)
#   - 더봄 애교살＆트임 펜슬 (쿨핑크)
#   - 더봄 애교살＆트임 펜슬 샴페인 베이지
#   - 더봄 미인점 펜 다크브라운
#
# [데일리콤마] (6개)
# --------------------------------------------------------------------------------
#   - 데일리콤마 오드 퍼퓸(미스티가든) 30 ml
#   - 데일리콤마 오드 퍼퓸(나이브머스크) 30 ml
#   - 데일리콤마 오드 퍼퓸(반타우드) 30 ml
#   - 데일리콤마 오 드 퍼퓸 30 ml 머스키시더
#   - 데일리콤마 오 드 퍼퓸 30 ml 프레시시트러스
#   - 데일리콤마 오 드 퍼퓸 30 ml 나티블루
#
# [도루코] (5개)
# --------------------------------------------------------------------------------
#   - 도루코 6중날 남성 면도기 2P
#   - 도루코 EVE 모이스처 6중날 휴대용 면도기
#   - 도루코 PACE4 4중날 면도기 5P
#   - 도루코 터치 3중날 3P 젤 3P SET
#   - 도루코 에코 쓰리 면도기 4개입
#
# [도루코TG2플러스5P] (1개)
# --------------------------------------------------------------------------------
#   - 도루코TG2플러스5P
#
# [도루코윈] (2개)
# --------------------------------------------------------------------------------
#   - 도루코윈 3중날 면도기 4P
#   - 도루코윈 3중날 면도기 1P
#
# [도루코윈3] (2개)
# --------------------------------------------------------------------------------
#   - 도루코윈3 시스템 면도기 세트
#   - 도루코윈3 시스템 3중 면도날 리필형 4P
#
# [도루코윈4] (2개)
# --------------------------------------------------------------------------------
#   - 도루코윈4 시스템 면도기 SET
#   - 도루코윈4 시스템 면도기 리필형 4P
#
# [둥근형] (1개)
# --------------------------------------------------------------------------------
#   - 둥근형 아이브로우 다크브라운
#
# [드롭비 컬러즈] (19개)
# --------------------------------------------------------------------------------
#   - [04 쉐딩 브론저] 드롭비 컬러즈쉐딩스틱
#   - [03 블러셔 로지 베리] 드롭비 컬러즈 블러셔 스틱
#   - [01 윤광 샴페인 빔] 드롭비 컬러즈 스틱
#   - [02 블러셔 피치문] 드롭비 컬러즈 블러셔 스틱
#   - 드롭비 컬러즈 커버픽 컨실러 클리어 베이지
#   - 드롭비 컬러즈 커버픽 컨실러 내추럴 베이지
#   - [03 살몬 베이지] 드롭비 컬러즈 컨실팟
#   - 드롭비 컬러즈 커버픽 컨실러 펜슬 내추럴 베이지
#   - [02 핑크] 드롭비 컬러즈 컨실팟
#   - [01 화이트] 드롭비 컬러즈 컨실팟
#   - [04 커버 베이지] 드롭비 컬러즈 컨실팟
#   - [01 페어 피치] 드롭비 컬러즈 아이 컨실러 스틱
#   - [02 뉴트럴 피치] 드롭비 컬러즈 아이 컨실러 스틱
#   - [01 라이트 베이지] 드롭비 컬러즈 커버픽 파운데이션 리뉴 35 g
#   - 드롭비 컬러즈 베일 스킨 톤업 베이스 35 g
#   - 드롭비 컬러즈 컬러픽 컨실러 피치
#   - 드롭비 컬러즈 커버픽 컨실러 펜슬 클리어 베이지
#   - 드롭비 컬러즈 컬러픽 컨실러 그린
#   - [02 내추럴 베이지] 드롭비 컬러즈 커버픽 파운데이션 리뉴 35 g
#
# [러블리] (3개)
# --------------------------------------------------------------------------------
#   - 러블리 메이크업 컬링 마스카라
#   - 러블리 메이크업 리퀴드아이라이너
#   - 러블리 메이크업 볼륨 마스카라
#
# [맨넨] (2개)
# --------------------------------------------------------------------------------
#   - 맨넨 스킨브레이서 포맨 마일드 스킨 165ml
#   - 맨넨 스킨브레이서 포맨 마일드 에멀젼 165ml
#
# [머지] (36개)
# --------------------------------------------------------------------------------
#   - [07 화이트링] 머지 렛츠웨어링 립앤치크 키링
#   - [05 핑크링] 머지 렛츠웨어링 립앤치크 키링
#   - [06 골드링] 머지 렛츠웨어링 립앤치크 키링
#   - 머지 렛츠 픽싱 슬림 젤 아이라이너 브론즈오팔
#   - 머지 렛츠 픽싱 슬림 젤 아이라이너 브라운쿼츠
#   - 머지 렛츠 픽싱 슬림 젤 아이라이너 블랙오닉스
#   - 머지 렛츠 픽싱 펜 아이라이너 브라우니
#   - [01 페일피오니] 머지 렛츠웨어링 아이섀도우
#   - 머지 렛츠 블링 듀얼 애교살 라이너 피치코랄펄
#   - [03 모브어필] 머지 렛츠웨어링 아이섀도우
#   - [07 베일베이지] 머지 렛츠웨어링 아이섀도우
#   - [05 애프리콧핑크] 머지 렛츠웨어링 아이섀도우
#   - [04 어텀퍼지] 머지 렛츠웨어링 아이섀도우
#   - [06 포지핑키드] 머지 렛츠웨어링 아이섀도우
#   - 머지 렛츠 블링 듀얼 애교살 라이너 크림베이지펄
#   - [08 핑크홀리] 머지 렛츠웨어링 아이섀도우
#   - 머지 렛츠 블링 듀얼 애교살 라이너 페일핑크펄
#   - 머지 렛츠 픽싱 마스카라 롱래쉬
#   - 머지 렛츠 스머징 아이 스틱 섀도우 로지필터
#   - 머지 렛츠 스머징 아이 스틱 섀도우 소프트살몬
#   - 머지 렛츠 스머징 아이 스틱 섀도우 클리어핑크
#   - 머지 렛츠 픽싱 마스카라 볼륨컬링
#   - 머지 렛츠 픽싱 펜 아이라이너 오레오
#   - [02 멜로우진저] 머지 렛츠웨어링 아이섀도우
#   - 머지 렛츠 스머징 아이 스틱 섀도우 모카브라운
#   - 머지 렛츠 픽싱 젤 아이라이너 더치브라운
#   - 머지 렛츠 픽싱 젤 아이라이너 블랙문
#   - [02 러브블룸] 머지 렛츠웨어링 블러틴트 키링
#   - [01 애플레드] 머지 렛츠웨어링 립앤치크 키링
#   - [03포그발레] 머지 렛츠웨어링 블러틴트 키링
#   - [08 블루밤] 머지 렛츠웨어링 립앤치크 키링
#   - [01 쿨베이비] 머지 렛츠웨어링 블러틴트 키링
#   - [04 베리핑크] 머지 렛츠웨어링 블러틴트 키링
#   - [02 리치로지] 머지 렛츠웨어링 립앤치크 키링
#   - [04 라벤더플럼] 머지 렛츠웨어링 립앤치크 키링
#   - [03 스위트피치] 머지 렛츠웨어링 립앤치크 키링
#
# [멘넨] (2개)
# --------------------------------------------------------------------------------
#   - 멘넨 스킨브레이서 포맨 쉐이빙 클렌징 폼 150 ml
#   - 멘넨 스킨 브레이서 포맨 올인원 플루이드 250ml
#
# [미팩토리] (2개)
# --------------------------------------------------------------------------------
#   - 미팩토리 오일쏙쏙피니쉬파우더팩트(핑크베이지) 5 g
#   - 미팩토리 오일쏙쏙피니쉬파우더팩트(화이트) 5 g
#
# [밀크터치 디어씽] (21개)
# --------------------------------------------------------------------------------
#   - [02 퓨어레몬]밀크터치 디어씽 페이스 컨투어 크림 브라이트너
#   - [01 페일화이트]밀크터치 디어씽 페이스 컨투어 크림 브라이트너
#   - 밀크터치 디어씽 블러리 이펙트 스무드 터치팟 뮤트메모리
#   - [01 허니빔]밀크터치 디어씽 글로우 이펙트 리퀴드 하이라이터
#   - [02 핑크빔]밀크터치 디어씽 글로우 이펙트 리퀴드 하이라이터
#   - 밀크터치 디어씽 블러리 이펙트 스무드 터치팟 소프트베이비
#   - 밀크터치 디어씽 블러리 이펙트 스무드 터치팟 윈터모카
#   - 밀크터치 디어씽 블러리 이펙트 스무드 터치팟 스프링피버
#   - [트와이스 지효 PICK] 밀크터치 디어씽 블러리 이펙트 스무드 터치팟 베리크러쉬
#   - 밀크터치 디어씽 글로우 이펙트 3D 하이라이터 페어리핑크
#   - 밀크터치 디어씽 글로우 이펙트 3D 하이라이터 듀이골드
#   - 밀크터치 디어씽 울트라 롱 컬링 마스카라(02 뮤트브라운)
#   - 밀크터치 디어씽 울트라 롱 컬링 마스카라(01 클리어블랙)
#   - [01 피치버니]밀크터치 디어씽 글로우 이펙트 젤리 터치팟
#   - [02 베리슈가]밀크터치 디어씽 글로우 이펙트 젤리 터치팟
#   - [03 애플무스]밀크터치 디어씽 글로우 이펙트 젤리 터치팟
#   - [05 오디퓌레]밀크터치 디어씽 글로우 이펙트 젤리 터치팟
#   - [04 체리드롭]밀크터치 디어씽 글로우 이펙트 젤리 터치팟
#   - 밀크터치 디어씽 글로우 이펙트 립 플럼퍼(02 오로라빔)
#   - 밀크터치 디어씽 글로우 이펙트 립 플럼퍼(01 클리어맥시)
#   - 밀크터치 디어씽 글로우 이펙트 립 플럼퍼(03 핑크빔)
#
# [방수] (1개)
# --------------------------------------------------------------------------------
#   - 방수 면도기
#
# [베리썸] (7개)
# --------------------------------------------------------------------------------
#   - [02 다크브라운] 베리썸 브로우타투팩
#   - [01 내추럴브라운] 베리썸 브로우타투팩
#   - [04 무화과칠리] 베리썸 립타투팩
#   - [02 구아바핑크] 베리썸 립타투팩
#   - [01 애플레드] 베리썸 립타투팩
#   - [03 리치코랄] 베리썸 립타투팩
#   - 베리썸 글램립오일
#
# [보닌] (4개)
# --------------------------------------------------------------------------------
#   - 보닌 알엑스 올인원클렌져 220ml (LG생활건강)
#   - 보닌 알엑스 페이셜딥클렌져 100ml (LG생활건강)
#   - 보닌 알엑스 애프터쉐이브스킨 250ml (LG생활건강)
#   - 보닌 알엑스 에센셜에멀젼 250ml (LG생활건강)
#
# [본셉 메이크업] (29개)
# --------------------------------------------------------------------------------
#   - [02 젤브라운] 본셉 젤 아이라이너
#   - 본셉 워터프루프 아이라이너 브라운
#   - [02 내추럴브라운] 본셉 슬림 픽싱 브로우카라
#   - [03 펄브라운] 본셉 젤 아이라이너
#   - 본셉 워터프루프 아이라이너 블랙
#   - [01 그레이브라운] 본셉 슬림 픽싱 브로우카라
#   - [01 제트블랙] 본셉 잉크 리퀴드 아이라이너
#   - [02 우디브라운] 본셉 잉크 리퀴드 아이라이너
#   - [03 골든카키] 본셉 잉크 리퀴드 아이라이너
#   - [01 젤블랙] 본셉 젤 아이라이너
#   - 본셉 수퍼 픽싱 아이브로우 그레이브라운
#   - [03 로즈티커] 본셉 립 타투 스티커
#   - [02 핑크티커] 본셉 립 타투 스티커
#   - 본셉 워터 베일 틴트 핑크워터
#   - [02 핑크쉬폰] 본셉 쉬폰 본딩 틴트
#   - 본셉 워터 베일 틴트 레드워터
#   - [01 살몬티커] 본셉 립 타투 스티커
#   - 본셉 워터 베일 틴트 살몬워터
#   - [03 로즈딥핑] 본셉 글레이즈 딥핑 틴트
#   - 본셉 수퍼 픽싱 틴트 코랄픽싱
#   - [03 로즈쉬폰] 본셉 쉬폰 본딩 틴트
#   - [01 코랄쉬폰] 본셉 쉬폰 본딩 틴트
#   - 본셉 수퍼 픽싱 틴트 플럼픽싱
#   - [01 애플딥핑] 본셉 글레이즈 딥핑 틴트
#   - 본셉 수퍼 픽싱 틴트 오렌지픽싱
#   - [02 스트로베리딥핑] 본셉 글레이즈 딥핑 틴트
#   - [01 클리어코팅] 본셉 모이스트 립글로스
#   - 본셉 워터 베일 틴트 로즈워터
#   - 본셉 수퍼 픽싱 틴트 핑크픽싱
#
# [비알티씨] (1개)
# --------------------------------------------------------------------------------
#   - BRTC 스킨 랩 옴므 시리즈 모공 클리어 패드 7 ml
#
# [손앤박] (26개)
# --------------------------------------------------------------------------------
#   - 손앤박 아티 스프레드 하이라이터 밤(01 클리어)
#   - 손앤박 아티 스프레드 하이라이터 밤(02 선라이즈)
#   - 손앤박 아티 스프레드 하이라이터 밤(03 문라이즈)
#   - 손앤박 아티 스프레드 블러 밤(03 멜로우)
#   - 손앤박 아티 스프레드 블러 밤(01 선셋)
#   - 손앤박 아티 스프레드 블러 밤(02 피오니)
#   - 손앤박 아티 스프레드 블러 밤(04 포피)
#   - 손앤박 아티 스프레드 블러 밤(05 모브)
#   - 손앤박 아티 스프레드 컬러 밤(04 하티)
#   - 손앤박 아티 스프레드 컬러 밤(05 포멜로)
#   - 손앤박 아티 스프레드 컬러 밤(03 멜로우)
#   - 손앤박 아티 스프레드 컬러 밤(01 선셋)
#   - 손앤박 아티 스프레드 컬러 밤(02 피오니)
#   - 손앤박 아티 워터 블러 틴트(02 코지레드)
#   - 손앤박 아티 샤인 립 플럼퍼(01 펄클리어)
#   - 손앤박 아티 워터 블러 틴트(03 로즈뮬리)
#   - 손앤박 아티 워터 글로우 틴트(02 듀이코랄)
#   - 손앤박 아티 워터 글로우 틴트(01 레드벨리)
#   - 손앤박 아티 스프레드 스파클 밤(03 헤일로)
#   - 손앤박 아티 워터 블러 틴트(01 피치썸)
#   - 손앤박 아티 워터 블러 틴트(04 그레이프콜드)
#   - 손앤박 아티 워터 글로우 틴트(04 플럼베리)
#   - 손앤박 아티 샤인 립 플럼퍼(02 무드블랙)
#   - 손앤박 아티 스프레드 스파클 밤(02 플레어)
#   - 손앤박 아티 스프레드 스파클 밤(01 베어)
#   - 손앤박 아티 워터 글로우 틴트(03 페어리핑크)
#
# [수채화] (1개)
# --------------------------------------------------------------------------------
#   - 수채화 음영 아이라이너 애쉬블랙
#
# [쉬크] (7개)
# --------------------------------------------------------------------------------
#   - 쉬크 하이드로 쉐이빙 폼 250g
#   - 쉬크 쉐이브 가드 210g 워시앤쉐이브 폼
#   - 쉬크 쉐이브가드 센서티브 라임폼 210g
#   - 쉬크 이그젝타 3중날 면도기 4P
#   - 쉬크 익스트림 3중날 면도기 4개입
#   - 쉬크 쿼트로 티타늄 휴대용 면도기 2개입
#   - 쉬크 익스트림 3중날 면도기 1개입
#
# [스니키] (1개)
# --------------------------------------------------------------------------------
#   - 스니키 톤보정 파운데이션 30 ml 내추럴 베이지
#
# [스타일리쉬] (8개)
# --------------------------------------------------------------------------------
#   - 스타일리쉬 붓펜 아이라이너 브라운
#   - 스타일리쉬 브러쉬아이라이너 브라운
#   - 스타일리쉬 붓펜 아이라이너 라이트브라운
#   - 스타일리쉬 오토아이브로우펜슬 회갈색 82호
#   - 스타일리쉬 오토아이브로우펜슬 흑갈색 22호
#   - 스타일리쉬 브러시아이라이너 블랙
#   - 스타일리쉬 오토아이브로우 펜슬 흑색 11호
#   - 스타일리쉬 붓펜 아이라이너 블랙
#
# [식물원] (2개)
# --------------------------------------------------------------------------------
#   - 식물원 플로라 노세범 파우더 팩트 4 g
#   - 식물원 플로라 노세범 파우더 4 g
#
# [심플] (1개)
# --------------------------------------------------------------------------------
#   - 심플 전동 코털 제거기
#
# [싸이닉] (6개)
# --------------------------------------------------------------------------------
#   - 싸이닉 파워옴므 퍼펙트클렌징폼 150 ml
#   - 싸이닉 파워옴므 블랙립밤 4 g
#   - 싸이닉 파워옴므 워터리선크림 50 ml
#   - 싸이닉 파워옴므 하이드로퍼밍올인원플루이드 150 ml
#   - 싸이닉 파워옴므 비타톤업올인원플루이드 150 ml
#   - 싸이닉 파워옴므 시카수딩올인원플루이드 150 ml
#
# [애교살] (3개)
# --------------------------------------------------------------------------------
#   - 애교살 음영 라이너 그림자
#   - 애교살 라이너 (베이지)
#   - 애교살 라이너 (핑크)
#
# [어퓨_더퓨어] (5개)
# --------------------------------------------------------------------------------
#   - 어퓨 더퓨어 캔디 워터 치크(03 비몽자몽)
#   - 어퓨 더퓨어 캔디 워터 치크(01 새해복숭아)
#   - 어퓨 더퓨어 캔디 틴트(03 예쁘면단감)
#   - 어퓨 더퓨어 캔디 틴트(01 땡큐체리머치)
#   - 어퓨 더퓨어 캔디 틴트(02 크크크림딸기)
#
# [오릭스] (3개)
# --------------------------------------------------------------------------------
#   - 오릭스 엘레강스 올인원 스킨＆로션 410 ml
#   - 오릭스 엘레강스 리프레싱 남성용 로션 365ml
#   - 오릭스 엘레강스 리프레싱 남성용 스킨 365ml
#
# [윙크걸] (3개)
# --------------------------------------------------------------------------------
#   - 윙크걸 아이돌 마스카라 컬링
#   - 윙크걸 아이돌 마스카라 볼륨
#   - 윙크걸 기름종이 파우더
#
# [입큰] (30개)
# --------------------------------------------------------------------------------
#   - 입큰 퍼스널 톤 쿠션 블러셔 핑크 슈
#   - 입큰 퍼스널 퍼퓸 파우더 블러셔 웜 코랄
#   - 입큰 퍼스널 퍼퓸 파우더 블러셔 아이시 베리
#   - 입큰 퍼스널 톤 쿠션 블러셔 누드 베어
#   - 입큰 퍼스널 톤 쿠션 블러셔 디어 코랄
#   - 입큰 퍼스널 톤 쿠션 블러셔 라벤더 온
#   - 입큰 퍼스널 톤 치크 라이터 듀오 웜 라이터
#   - 입큰 퍼스널 퍼퓸 파우더 블러셔 뮤티드 베이지
#   - 입큰 퍼스널 퍼퓸 파우더 블러셔 쿨 라벤더
#   - 입큰 퍼스널 톤 치크 라이터 듀오 쿨 라이터
#   - 입큰 퍼스널 톤 코렉팅 블러 팩트 5.5 g(라벤더)
#   - 입큰 퍼스널 톤 코렉팅 블러 팩트 5.5 g(그린)
#   - 입큰 퍼스널 톤 코렉팅 파우더 라벤더
#   - 입큰 퍼스널수분프라이머 25 ml
#   - 입큰 퍼스널 퍼퓸 파우더팩트 (21호) 9g
#   - 입큰 퍼스널톤 코렉팅 베이스 (라벤더) 25ml
#   - 입큰 퍼스널 프라이머 (톤업) 25ml
#   - 입큰 퍼스널톤 코렉팅 베이스 (그린) 25ml
#   - 입큰 퍼스널 퍼퓸 파우더팩트 (23호) 9g
#   - 입큰 퍼스널 톤업 쿠션 13 g
#   - 입큰 퍼스널 톤 코렉팅 컨실러 듀오 라벤더
#   - 입큰 퍼스널 톤 코렉팅 파우더 그린
#   - 입큰 퍼스널 톤 커버 쿠션 15 g 23호
#   - 입큰 퍼스널 톤 코렉팅 컨실러 듀오 그린
#   - 입큰 퍼스널 프라이머 (포어) 25ml
#   - 입큰 퍼스널 톤 커버 쿠션 15 g 21호
#   - 입큰 퍼스널 톤 틴티드 글로스 듀오 허그 핑크
#   - 입큰 퍼스널 톤 틴티드 글로스 듀오 피즈 코랄
#   - 입큰 퍼스널 톤 틴티드 글로스 듀오 애플 퓨레
#   - 입큰 퍼스널 톤 틴티드 글로스 듀오 피오니 바인
#
# [잇츠스킨] (1개)
# --------------------------------------------------------------------------------
#   - 잇츠스킨 세븐펩타이드콜라겐 비비크림 50ml
#
# [전동] (1개)
# --------------------------------------------------------------------------------
#   - 전동 코털정리기 세트
#
# [제이엠솔루션] (2개)
# --------------------------------------------------------------------------------
#   - 제이엠솔루션 아크클리어 클렌징폼 150 ml
#   - 제이엠솔루션 아크클리어 올인원에멀전 150 ml
#
# [줌 바이 정샘물] (11개)
# --------------------------------------------------------------------------------
#   - [21호 엔라이트]줌 바이 정샘물 새틴핏 스파츌라 파운데이션 25 ml
#   - 줌 바이 정샘물 광프렙 부스터 30 ml
#   - [23호 미디엄]줌 바이 정샘물 새틴핏 스파츌라 파운데이션 25 ml
#   - 줌 바이 정샘물 글로시업 쿠션
#   - 줌 바이 정샘물 세범다운 쿠션
#   - [21호 엔라이트]줌 바이 정샘물 듀이핏 스파츌라 파운데이션 25 ml
#   - [19호 페어라이트]줌 바이 정샘물 새틴핏 스파츌라 파운데이션 25 ml
#   - 줌 바이 정샘물 톤프렙 부스터 30 ml
#   - 줌 바이 정샘물 메이크업 픽서 50 ml
#   - [19호 페어라이트]줌 바이 정샘물 듀이핏 스파츌라 파운데이션 25 ml
#   - [23호 미디엄]줌 바이 정샘물 듀이핏 스파츌라 파운데이션 25 ml
#
# [카이지루시] (1개)
# --------------------------------------------------------------------------------
#   - 카이지루시 남성용 2중날 면도기＆리필 5개입
#
# [캐릭터] (1개)
# --------------------------------------------------------------------------------
#   - 캐릭터 리파이닝 로션 350ml
#
# [코드글로컬러] (3개)
# --------------------------------------------------------------------------------
#   - 코드글로컬러 핑크 블러 컨트롤 베이스 30 ml
#   - 코드글로컬러 포어 블러 컨트롤 밤 7 g
#   - 코드글로컬러 포어 블러 컨트롤 베이스 30 ml
#
# [코시에로] (10개)
# --------------------------------------------------------------------------------
#   - [101 페탈]코시에로 아이콘 컬러완드
#   - [301 웜쉐이드]코시에로 아이콘 컬러완드
#   - [201 문릿글로우]코시에로 아이콘 컬러완드
#   - [104 드라이로즈]코시에로 아이콘 컬러완드
#   - [103 체리레드]코시에로 아이콘 컬러완드
#   - [102 코랄버스트]코시에로 아이콘 컬러완드
#   - [04 로즈더스크]코시에로 아이콘 워터벨벳 플럼퍼
#   - [01 페어리핑크]코시에로 아이콘 워터벨벳 플럼퍼
#   - [02 체리쉬]코시에로 아이콘 워터벨벳 플럼퍼
#   - [03 멜로우코랄]코시에로 아이콘 워터벨벳 플럼퍼
#
# [코코가가] (10개)
# --------------------------------------------------------------------------------
#   - [유니스 엘리시아 PICK] 그루밍 벨벳 틴트(01 청순냥) (코코가가 바이 포렌코즈)
#   - 코코가가 바이 포렌코즈 냥 젤리 글로우 틴트(03 로즈젤리)
#   - 코코가가 바이 포렌코즈 그루밍 벨벳 틴트(02 친절냥)
#   - [유니스 임서원 PICK] 냥 젤리 글로우 틴트(01 살구젤리) (코코가가 바이 포렌코즈)
#   - 코코가가 바이 포렌코즈 냥 젤리 글로우 틴트(02 딸기젤리)
#   - [유니스 코토코 PICK] 러블리 캣 무드 체인지 립 타퍼(01 아깽이블루) (코코가가 바이 포렌코즈)
#   - 코코가가 바이 포렌코즈 그루밍 벨벳 틴트(03 새침냥)
#   - 코코가가 바이 포렌코즈 그루밍 벨벳 틴트(04 시크냥)
#   - 코코가가 바이 포렌코즈 러블리 캣 무드 체인지 립 타퍼(02 무릎냥브라운)
#   - 코코가가 바이 포렌코즈 냥 젤리 글로우 틴트(04 포도젤리)
#
# [클라뷰] (9개)
# --------------------------------------------------------------------------------
#   - 클라뷰 밸런싱 포어밤 프라이머 10 ml
#   - 클라뷰 밸런싱 워터크림 25 ml
#   - 클라뷰 밸런싱 리퀴드 선베이스 30 ml
#   - 클라뷰 밸런싱 팟컨실러 01 라이트베이지 5 g
#   - 클라뷰 밸런싱 리퀴드 톤커버베이스 30 ml
#   - 클라뷰 밸런싱 팟컨실러 02 내추럴베이지 5 g
#   - 클라뷰 밸런싱 글로우빔 화이트펄 30 ml
#   - 클라뷰 밸런싱 리퀴드 톤업베이스 30 ml
#   - 클라뷰 밸런싱 글로우빔 핑크펄 30 ml
#
# [클리덤] (2개)
# --------------------------------------------------------------------------------
#   - 클리덤 리포좀 비타민C 기미 앰플 밤 팩트(21호) 10 g
#   - 클리덤 리포좀 비타민C 기미 앰플 밤 팩트(23호) 10 g
#
# [태그] (42개)
# --------------------------------------------------------------------------------
#   - 태그 무드블러쉬빔(2호_페어모브) 9 g
#   - 태그 멀티 컨투어 스틱 누드 브라운
#   - 태그 듀얼멀티쉐딩(1호_소프트웜) 9.4 g
#   - 태그 듀얼 멀티 쉐딩 9.4g 모노 쿨
#   - 태그 멀티 컨투어 스틱 누드 베이지
#   - 태그 볼륨하이라이터빔(1호_오팔화이트)
#   - 태그 무드블러쉬빔(3호_퓨어라벤더) 9 g
#   - 태그 볼륨하이라이터빔(3호_베일샴페인)
#   - 태그 볼륨하이라이터빔(2호_블룸핑크)
#   - 태그 멀티 컨투어 스틱 누드 로지
#   - 태그 무드 블러쉬 빔 9g 베어 코랄
#   - 태그 슬림 브로우 펜슬 다크 브라운
#   - 태그 슬림 브로우 펜슬 라이트 브라운
#   - 태그 에어 픽싱 브로우 카라 9g 다크 브라운
#   - 태그 에어 픽싱 브로우 카라 9g 라이트 브라운
#   - 태그 슬림 핏 아이라이너 뮤티드 브라운
#   - 태그 슬림 핏 아이라이너 다크 브라운
#   - 태그 파우더브로우키트(1호_애쉬브라운)
#   - 태그 파우더브로우키트(2호_내추럴브라운)
#   - 태그 슬림브로우펜슬(2호_애쉬브라운)
#   - 태그 슬림 핏 아이라이너 애쉬 블랙
#   - 태그 코렉팅선베이스(3호_클리어블루) 32 ml
#   - 태그 벨벳 커버 쿠션 15g 페일 라이트
#   - 태그 벨벳 커버 쿠션 15g 누드 라이트
#   - 태그 벨벳 세팅 픽서 100 ml
#   - 태그 코렉팅선베이스(2호_소프트핑크) 32 ml
#   - 태그 코렉팅선베이스(1호_글림아이보리) 32 ml
#   - 태그 듀이 스킨 쿠션 15g 누드 라이트
#   - 태그 스킨핏커버밤(2호_내추럴베이지) 12 g
#   - 태그 스킨핏커버밤(1호_라이트베이지) 12 g
#   - 태그 톤업선파우더(1호_페일라이트) 5 g
#   - 태그 톤업선파우더(3호_블루라이트) 5 g
#   - 태그 톤업선파우더(2호_핑크라이트) 5 g
#   - 태그 듀이 스킨 쿠션 15g 페일 라이트
#   - 태그 듀이멜팅밤(2호_로즈티)
#   - 태그 듀이멜팅밤(3호_피그휘그)
#   - 태그 벨벳블러밤(1호_멀린피치)
#   - 태그 듀이멜팅밤(1호_코랄피즈)
#   - 태그 듀이멜팅밤(4호_디어핑크)
#   - 태그 벨벳블러밤(2호_모브휘슬)
#   - 태그 벨벳블러밤(3호_핑크헤일로)
#   - 태그 벨벳블러밤(4호_하티핑크)
#
# [투에딧] (32개)
# --------------------------------------------------------------------------------
#   - 투에딧 바이 루나 컨투어링 쉐딩 멀티 스틱(02 쿨스텝)
#   - 투에딧 바이 루나 컨투어링 하이라이터 멀티 스틱(02 핑크라이트)
#   - [선우 PICK] 투에딧 바이 루나 컨투어링 하이라이터 멀티 스틱(01 베일라이트)
#   - [선우 PICK] 투에딧 바이 루나 컨투어링 쉐딩 멀티 스틱(01 웜스텝)
#   - 투에딧 바이 루나 이지 드로잉 아이브로우(01 그레이브라운)
#   - 투에딧 바이 루나 메이킹 트임 아이라이너(01 아이싱블랙)
#   - 투에딧 바이 루나 메이킹 트임 아이라이너(02 번트브라운)
#   - 투에딧 바이 루나 이지 드로잉 아이브로우(02 다크브라운)
#   - 투에딧 바이 루나 터치 업 스틱 아이섀도우(01 샴페인베이지)
#   - 투에딧 바이 루나 터치 업 스틱 아이섀도우(03 피치코랄)
#   - 투에딧 바이 루나 터치 업 스틱 아이섀도우(02 스프링핑크)
#   - [선우 PICK] 투에딧 바이 루나 메이킹 트임 아이라이너(05 쿨모브)
#   - 투에딧 바이 루나 메이킹 트임 아이라이너(04 웜살몬)
#   - 투에딧 바이 루나 메이킹 트임 아이라이너(03 언더브라운)
#   - 투에딧 바이 루나 이지 드로잉 아이브로우(03 소프트브라운)
#   - 투에딧 바이 루나 [01 라이트]투에딧 반질커버 쿠션 13 g X세숑
#   - 투에딧 바이 루나 [01 라이트]투에딧 밀착커버 컨실러X세숑
#   - 투에딧 바이 루나 [03 피치살몬]투에딧 밀착커버 컨실러X세숑
#   - 투에딧 바이 루나 투에딧 반질밀착 베이스 30 ml X세숑
#   - [선우 PICK] 투에딧 바이 루나 스킨 커버 컨실 팔레트(01 톤커버)
#   - 투에딧 바이 루나 [02 내추럴]투에딧 밀착커버 컨실러 X세숑
#   - 투에딧 바이 루나 스킨 커버 컨실 팔레트(02 톤코렉팅라이트)
#   - 투에딧 바이 루나 [02 내추럴]투에딧 반질커버 쿠션 13 g X세숑
#   - 투에딧 바이 루나 블러 파우더 팩트(02 클린화이트)
#   - 투에딧 바이 루나 반질코팅 메이크업픽서 100 ml X세숑
#   - 투에딧 바이 루나 블러 파우더 팩트(01 페일핑크)
#   - 투에딧 바이 루나 스머징 립앤치크 멀티 스틱(02 소프트핑크)
#   - 투에딧 바이 루나 볼류밍 글레이즈 빔(01 코코넛애프리콧)
#   - 투에딧 바이 루나 스머징 립앤치크 멀티 스틱(03 레어로즈)
#   - [선우 PICK] 투에딧 바이 루나 스머징 립앤치크 멀티 스틱(01 멜로우살몬)
#   - 투에딧 바이 루나 볼류밍 글레이즈 빔(02 뮤트피그)
#   - 투에딧 바이 루나 볼류밍 글레이즈 빔(03 클리어베리)
#
# [트윙클팝] (27개)
# --------------------------------------------------------------------------------
#   - [03 로지멜로우]트윙클팝 소프티 듀오 치크 밤 by CLIO
#   - [02 피치무스]트윙클팝 소프티 듀오 치크 밤 by CLIO
#   - [01 페탈블룸]트윙클팝 소프티 듀오 치크 밤 by CLIO
#   - 트윙클팝 레이어링 무드 팔레트(02 피치블렌딩) by CLIO
#   - 트윙클팝 레이어링 무드 팔레트(01 핑크셀렉션) by CLIO
#   - 트윙클팝 스파클링 아이 스틱 라벤더튀튀 by CLIO
#   - 트윙클팝 레이어링 무드 팔레트(03 카라멜글레이즈) by CLIO
#   - 트윙클팝 퓨어 글래스 틴트(01 미들로즈) by CLIO
#   - 트윙클팝 퓨어 글래스 틴트(05 쿨체리) by CLIO
#   - 트윙클팝 오버 립 펜슬 웜 살몬 by CLIO
#   - 트윙클팝 오버 립 펜슬 쿨스트로베리 by CLIO
#   - 트윙클팝 탱글 컬러 글로스(01 버니베베) by CLIO
#   - [01 피오니엔젤]트윙클팝 탱글 젤링 팟 by CLIO
#   - 트윙클팝 퓨어 글래스 틴트(04 봄라피치) by CLIO
#   - 트윙클팝 블러 머드 팟(02 피치센트) by CLIO
#   - 트윙클팝 블러 머드 팟(04 바밍핑크) by CLIO
#   - [04 모카로즈]트윙클팝 탱글 젤링 팟 by CLIO
#   - 트윙클팝 탱글 컬러 글로스(03 자몽베베) by CLIO
#   - [03 그레이프듀]트윙클팝 탱글 젤링 팟 by CLIO
#   - [02 허니피치]트윙클팝 탱글 젤링 팟 by CLIO
#   - 트윙클팝 탱글 컬러 글로스(02 앵두베베) by CLIO
#   - 트윙클팝 오버 립 펜슬 애쉬 베이지 by CLIO
#   - 트윙클팝 블러 머드 팟(03 베일모브) by CLIO
#   - 트윙클팝 블러 머드 팟(01 핑크테이프) by CLIO
#   - 트윙클팝 퓨어 글래스 틴트(02 쿨모브) by CLIO
#   - 트윙클팝 오버 립 펜슬 뉴트럴피치 by CLIO
#   - 트윙클팝 오버 립 펜슬 쿨 핑크 by CLIO
#
# [파넬] (4개)
# --------------------------------------------------------------------------------
#   - 파넬 피치마누세럼쿠션파운데이션 21호
#   - 파넬 피치마누세럼쿠션파운데이션 23호
#   - 파넬 피치마누틴티드톤업세럼 30 ml
#   - 파넬 피치마누틴티드커버세럼 30 ml
#
# [펜슬] (2개)
# --------------------------------------------------------------------------------
#   - 펜슬 브러시 아이브로우 그레이브라운
#   - 펜슬 브러시 아이브로우 다크브라운
#
# [펜슬＆브러쉬] (1개)
# --------------------------------------------------------------------------------
#   - 펜슬＆브러쉬 아이브로우 (초코브라운)
#
# [펠트] (2개)
# --------------------------------------------------------------------------------
#   - 펠트 롱슬림 라이너 블랙
#   - 펠트 롱슬림 라이너 브라운
#
# [프렙 바이 비레디] (6개)
# --------------------------------------------------------------------------------
#   - 프렙바이비레디 헬시톤 커버로션 30 ml_아모레퍼시픽
#   - 프렙바이비레디 헬시톤 립밤 매트 4.2 g_아모레퍼시픽
#   - 프렙바이비레디 히카페인 초촉촉 올인원 150 g_아모레퍼시픽
#   - 프렙바이비레디 헬시톤 립밤 촉촉 6.5 g_아모레퍼시픽
#   - 프렙바이비레디 히카페인 편백수 스킨토너 200 ml_아모레퍼시픽
#   - 프렙바이비레디 히카페인 오일컷 올인원 150 g_아모레퍼시픽
#
# [프릴루드 딘토] (31개)
# --------------------------------------------------------------------------------
#   - [63 마담 로즈]프릴루드 딘토 라벨르로즈 리퀴드치크 10 ml
#   - [61 베이비 로즈]프릴루드 딘토 라벨르로즈 리퀴드치크 10 ml
#   - [62 레이디 로즈]프릴루드 딘토 라벨르로즈 리퀴드치크 10 ml
#   - [64 뮤즈 로즈]프릴루드 딘토 라벨르로즈 리퀴드치크 10 ml
#   - [72 리틀 오스틴]프릴루드 딘토 노스탈지아 아이 팔레트
#   - [71 리틀 올콧]프릴루드 딘토 노스탈지아 아이 팔레트
#   - [73 리틀 살로메]프릴루드 딘토 노스탈지아 아이 팔레트
#   - [74 리틀 로르카]프릴루드 딘토 노스탈지아 아이 팔레트
#   - [52 인더다크]프릴루드 딘토 단테 트리플 프루프 슬림 아이라이너
#   - [51 어비스]프릴루드 딘토 단테 트리플 프루프 슬림 아이라이너
#   - [53 인더라이트]프릴루드 딘토 단테 트리플 프루프 슬림 아이라이너
#   - [41 레오네]프릴루드 딘토 단테 샤프너블 브로우 펜슬
#   - [42 판테라]프릴루드 딘토 단테 샤프너블 브로우 펜슬
#   - [43 루포]프릴루드 딘토 단테 샤프너블 브로우 펜슬
#   - [92 세이지 운초]프릴루드 딘토 운초 블러 매트 리퀴드 파운데이션 25 ml
#   - [93 캄 운초]프릴루드 딘토 운초블러 래디언스 쿠션 15 g
#   - [01 밀키 페어리]프릴루드 딘토 페어리 더스트 루스 파우더 5 g
#   - [02 피치 페어리]프릴루드 딘토 페어리 더스트 루스 파우더 5 g
#   - [03 블루벨 페어리]프릴루드 딘토 페어리 더스트 루스 파우더 5 g
#   - [91 퓨어 운초]프릴루드 딘토 운초 블러 매트 리퀴드 파운데이션 25 ml
#   - [92 세이지 운초]프릴루드 딘토 운초블러 래디언스쿠션 15 g
#   - [91 퓨어 운초]프릴루드 딘토 운초블러 래디언스 쿠션 15 g
#   - [93 캄 운초]프릴루드 딘토 운초 블러 매트 리퀴드 파운데이션 25 ml
#   - [12 헤이지 로즈]프릴루드 딘토 라벨르로즈 립라이너
#   - [11 미스티 로즈]프릴루드 딘토 라벨르로즈 립라이너
#   - [21 이브닝 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#   - [23 던 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#   - [24 더스크 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#   - [25 모닝 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#   - [22 미드나잇 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#   - [26 눈 로즈]프릴루드 딘토 라벨르 로즈 플럼핑 립틴트
#
# [플랫형] (2개)
# --------------------------------------------------------------------------------
#   - 플랫형 아이브로우 내추럴브라운
#   - 플랫형 아이브로우 다크브라운
#
# [플레이101 by 에뛰드] (25개)
# --------------------------------------------------------------------------------
#   - [02 쿨러 댄 미] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 파우더 블러셔
#   - [01 빔 쏘는 라이츄] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 크림 하이라이터
#   - [01 웜 스피릿] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 파우더 블러셔
#   - [01 센터 본능 씬 스틸러] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 하이라이터
#   - [01 상큼 자몽 타르트] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 크림 블러셔
#   - [02 아이스 베리 셔벗] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 크림 블러셔
#   - [02 빔 쏘는 베리츄] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 크림 하이라이터
#   - [02 은밀한 추리사건] 플레이 101 바이 에뛰드 멀티 블렌딩 피스 하이라이터
#   - 플레이 101 바이 에뛰드 엣지 컬 틴트 마스카라 블랙
#   - [01 봄 신상 등판] 플레이 101 바이 에뛰드 듀얼 아이피스
#   - [02 쿨 블레스 유] 플레이 101 바이 에뛰드 듀얼 아이 피스
#   - [03 홀린 듯 정주행] 플레이 101 바이 에뛰드 듀얼 아이 피스
#   - [03 반짝 반짝 작은 별] 플레이 101 바이 에뛰드 쥬얼 글리터 라이너
#   - [01 반짝 눈물 요정] 플레이 101 바이 에뛰드 쥬얼 글리터 라이너
#   - [04 시럽 추가 테이크 아웃] 플레이 101 바이 에뛰드 듀얼 아이피스
#   - 플레이 101 바이 에뛰드 엣지 컬 트위스트 마스카라 블랙
#   - 플레이 101 바이 에뛰드 엣지 컬 부스터 베이스 크림
#   - [02 엔젤 오브 엔젤] 플레이 101 바이 에뛰드 쥬얼 글리터 라이너
#   - [02 라이트 핑크] 플레이 101 바이 에뛰드 피니쉬 루스 파우더 5 g
#   - [01 라이트 베이지] 플레이 101 바이 에뛰드 피니쉬 루스 파우더 5 g
#   - [01 핑크 베이지] 플레이 101 바이 에뛰드 플럼핑 립 프라이머
#   - [02 피치 베이지] 플레이 101 바이 에뛰드 플럼핑 립 프라이머
#   - [01 듀이 피치] 플레이 101 바이 에뛰드 컬러링 글로스
#   - [02 츄이 핑크] 플레이 101 바이 에뛰드 컬러링 글로스
#   - [03 쥬시 캔디] 플레이 101 바이 에뛰드 컬러링 글로스
#
# [하드] (2개)
# --------------------------------------------------------------------------------
#   - 하드 우드 아이브로우 펜슬 그레이브라운
#   - 하드 우드 아이브로우 펜슬 내추럴브라운

# %% [markdown]
# # Parquet 파일 생성
# 모든 CSV 파일을 하나의 products.parquet과 reviews.parquet으로 통합

# %%
data_dir = '/Users/yu_seok/Documents/workspace/nbCamp/Project/Why-pi/data/csv'

# 1. Product CSV 파일들 통합
print("="*80)
print("Product CSV 파일 통합")
print("="*80)

product_files = glob.glob(os.path.join(data_dir, 'product_*.csv'))
print(f"발견된 product CSV: {len(product_files)}개\n")

all_products = []
for product_file in product_files:
    df = pd.read_csv(product_file)
    print(f"  - {os.path.basename(product_file)}: {len(df)}개 제품")
    all_products.append(df)

# Product 데이터 통합
if all_products:
    products_df = pd.concat(all_products, ignore_index=True)
    
    # 중복 제거 (product_code 기준)
    before_dedup = len(products_df)
    products_df = products_df.drop_duplicates(subset=['product_code'], keep='first')
    after_dedup = len(products_df)
    
    print(f"\n통합 전 총 제품 수: {before_dedup}개")
    print(f"중복 제거 후: {after_dedup}개 (중복 {before_dedup - after_dedup}개 제거)")
    
    # Parquet으로 저장
    output_path = os.path.join(data_dir, 'products.parquet')
    products_df.to_parquet(output_path, index=False, engine='pyarrow')
    print(f"\n✓ 저장 완료: {output_path}")
    print(f"  파일 크기: {os.path.getsize(output_path):,} bytes")
else:
    print("Product 데이터가 없습니다.")

print()
# Out:
# ================================================================================
# Product CSV 파일 통합
# ================================================================================
# 발견된 product CSV: 4개
#
#   - product_메이크업_치크_하이라이터_20260204.csv: 81개 제품
#   - product_메이크업_아이메이크업_20260204.csv: 128개 제품
#   - product_메이크업_베이스:립메이크업_20260204.csv: 237개 제품
#   - product_맨케어_all_20260204.csv: 73개 제품
#
# 통합 전 총 제품 수: 519개
# 중복 제거 후: 519개 (중복 0개 제거)
#
# ✓ 저장 완료: /Users/yu_seok/Documents/workspace/nbCamp/Project/Why-pi/data/csv/products.parquet
#   파일 크기: 34,021 bytes

# %%
# 2. Reviews CSV 파일들 통합
print("="*80)
print("Reviews CSV 파일 통합")
print("="*80)

review_files = glob.glob(os.path.join(data_dir, 'reviews_*.csv'))
print(f"발견된 reviews CSV: {len(review_files)}개\n")

all_reviews = []
for review_file in review_files:
    df = pd.read_csv(review_file)
    print(f"  - {os.path.basename(review_file)}: {len(df)}개 리뷰")
    all_reviews.append(df)

# Reviews 데이터 통합
if all_reviews:
    reviews_df = pd.concat(all_reviews, ignore_index=True)
    
    # 중복 제거 (user, product_code, date, text 조합으로 판단)
    before_dedup = len(reviews_df)
    reviews_df = reviews_df.drop_duplicates(
        subset=['user', 'product_code', 'date', 'text'], 
        keep='first'
    )
    after_dedup = len(reviews_df)
    
    print(f"\n통합 전 총 리뷰 수: {before_dedup}개")
    print(f"중복 제거 후: {after_dedup}개 (중복 {before_dedup - after_dedup}개 제거)")
    
    # Parquet으로 저장
    output_path = os.path.join(data_dir, 'reviews.parquet')
    reviews_df.to_parquet(output_path, index=False, engine='pyarrow')
    print(f"\n✓ 저장 완료: {output_path}")
    print(f"  파일 크기: {os.path.getsize(output_path):,} bytes")
    
    # 통계 출력
    print(f"\n리뷰 통계:")
    print(f"  고유 제품 수: {reviews_df['product_code'].nunique()}개")
    print(f"  고유 사용자 수: {reviews_df['user'].nunique()}명")
else:
    print("Reviews 데이터가 없습니다.")

print()
# Out:
# ================================================================================
# Reviews CSV 파일 통합
# ================================================================================
# 발견된 reviews CSV: 4개
#
#   - reviews_메이크업_치크_하이라이터_20260204.csv: 12883개 리뷰
#   - reviews_메이크업_아이메이크업_20260204.csv: 24386개 리뷰
#   - reviews_메이크업_베이스:립메이크업_20260204.csv: 55710개 리뷰
#   - reviews_맨케어_all_20260204.csv: 5651개 리뷰
#
# 통합 전 총 리뷰 수: 98630개
# 중복 제거 후: 98379개 (중복 251개 제거)
#
# ✓ 저장 완료: /Users/yu_seok/Documents/workspace/nbCamp/Project/Why-pi/data/csv/reviews.parquet
#   파일 크기: 5,968,328 bytes
#
# 리뷰 통계:
#   고유 제품 수: 514개
#   고유 사용자 수: 12335명

# %%
# 찐최종 검증
print("="*80)
print("최종 검증")
print("="*80)

# Parquet 파일 다시 읽기
products_path = os.path.join(data_dir, 'products.parquet')
reviews_path = os.path.join(data_dir, 'reviews.parquet')

if os.path.exists(products_path) and os.path.exists(reviews_path):
    products_check = pd.read_parquet(products_path)
    reviews_check = pd.read_parquet(reviews_path)
    
    print(f"\nproducts.parquet:")
    print(f"  레코드 수: {len(products_check):,}개")
    print(f"  컬럼 수: {len(products_check.columns)}개")
    print(f"  컬럼: {', '.join(products_check.columns.tolist())}")
    
    print(f"\nreviews.parquet:")
    print(f"  레코드 수: {len(reviews_check):,}개")
    print(f"  컬럼 수: {len(reviews_check.columns)}개")
    print(f"  컬럼: {', '.join(reviews_check.columns.tolist())}")
    
    # 매칭 검증
    product_codes_in_products = set(products_check['product_code'].unique())
    product_codes_in_reviews = set(reviews_check['product_code'].unique())
    
    matched = product_codes_in_products & product_codes_in_reviews
    only_in_products = product_codes_in_products - product_codes_in_reviews
    only_in_reviews = product_codes_in_reviews - product_codes_in_products
    
    print(f"\n{'='*80}")
    print("매칭 검증")
    print(f"{'='*80}")
    print(f"  [OK] 양쪽에 모두 있는 제품: {len(matched)}개")
    print(f"  [INFO] product만 있음 (리뷰 없음): {len(only_in_products)}개")
    print(f"  [WARNING] review만 있음 (제품 정보 없음): {len(only_in_reviews)}개")
    
    # 매칭 안되는 제품 상세 정보
    if len(only_in_products) > 0:
        print(f"\n{'='*80}")
        print("리뷰가 없는 제품 (product만 있음)")
        print(f"{'='*80}")
        no_review_products = products_check[products_check['product_code'].isin(only_in_products)]
        for idx, row in no_review_products.iterrows():
            print(f"\n  제품코드: {row['product_code']}")
            print(f"  브랜드: {row['brand']}")
            print(f"  제품명: {row['name']}")
            print(f"  카테고리: {row['category_1']} > {row['category_2']}")
            print(f"  가격: {row['price']}원")
    
    if len(only_in_reviews) > 0:
        print(f"\n{'='*80}")
        print("제품 정보가 없는 리뷰 (review만 있음)")
        print(f"{'='*80}")
        print(f"  제품 코드: {sorted(only_in_reviews)}")
        
        # 리뷰만 있는 제품의 리뷰 수 확인
        orphan_reviews = reviews_check[reviews_check['product_code'].isin(only_in_reviews)]
        review_counts = orphan_reviews['product_code'].value_counts()
        print(f"\n  제품별 리뷰 수:")
        for code, count in review_counts.items():
            print(f"    제품코드 {code}: {count}개 리뷰")
    
    print(f"\n{'='*80}")
    print("✓ Parquet 파일 생성 및 검증 완료!")
    print(f"{'='*80}")
else:
    print("Parquet 파일이 생성되지 않았습니다.")
# Out:
# ================================================================================
# 최종 검증
# ================================================================================
#
# products.parquet:
#   레코드 수: 519개
#   컬럼 수: 14개
#   컬럼: product_code, category_home, category_1, category_2, brand, name, price, country, likes, shares, url, can_할랄인증, can_비건, certifications
#
# reviews.parquet:
#   레코드 수: 98,379개
#   컬럼 수: 7개
#   컬럼: product_code, date, user_masked, user, rating, text, image_count
#
# ================================================================================
# 매칭 검증
# ================================================================================
#   [OK] 양쪽에 모두 있는 제품: 514개
#   [INFO] product만 있음 (리뷰 없음): 5개
#   [WARNING] review만 있음 (제품 정보 없음): 0개
#
# ================================================================================
# 리뷰가 없는 제품 (product만 있음)
# ================================================================================
#
#   제품코드: 1069087
#   브랜드: [01
#   제품명: [01 딥브라운] 더봄 스키니브로우 펜슬
#   카테고리: 메이크업 > 아이메이크업
#   가격: 2000원
#
#   제품코드: 1069088
#   브랜드: [02
#   제품명: [02 내추럴브라운] 더봄 스키니브로우 펜슬
#   카테고리: 메이크업 > 아이메이크업
#   가격: 2000원
#
#   제품코드: 1069090
#   브랜드: [04
#   제품명: [04 토프베이지] 더봄 스키니브로우 펜슬
#   카테고리: 메이크업 > 아이메이크업
#   가격: 2000원
#
#   제품코드: 1069089
#   브랜드: [03
#   제품명: [03 소프트그레이] 더봄 스키니브로우 펜슬
#   카테고리: 메이크업 > 아이메이크업
#   가격: 2000원
#
#   제품코드: 1059931
#   브랜드: KAI
#   제품명: KAI 2중날 고정식 면도기 5개입
#   카테고리: 맨케어 > 남성용면도기
#   가격: 2000원
#
# ================================================================================
# ✓ Parquet 파일 생성 및 검증 완료!
# ================================================================================
